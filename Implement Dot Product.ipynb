# %%
import numpy as np

def dot_product(x, y):
    """
    Compute the dot product of two 1D arrays x and y.
    Must return a float.
    """
    # Write code here

    product = (np.dot(x,y))
    return float(product)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       3 def dot_product(x, y):
#       4     """
#       5     Compute the dot product of two 1D arrays x and y.
#       6     Must return a float.
#       7     """
#
# ModuleNotFoundError: No module named 'numpy'
